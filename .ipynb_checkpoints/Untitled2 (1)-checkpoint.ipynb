# %%
import matplotlib.pyplot as plt
from sklearn.ensemble import RandomForestRegressor
from sklearn.model_selection import GroupKFold
from sklearn.feature_selection import RFECV
from sklearn.datasets import make_classification
import pandas as pd
from sklearn.model_selection import cross_val_score
from sklearn.metrics import mean_absolute_error
import numpy as np
from joblib import dump, load

# %%
cols = ['I_1_lag_20',
 'I_1_lag_19',
 'I_1_lag_18',
 'I_1_lag_17',
 'I_1_lag_16',
 'I_1_lag_15',
 'I_1_lag_14',
 'I_1_lag_13',
 'I_1_lag_12',
 'I_1_lag_11',
 'I_1_lag_10',
 'I_1_lag_9',
 'I_1_lag_8',
 'I_1_lag_7',
 'I_1_lag_6',
 'I_1_lag_5',
 'I_1_lag_4',
 'I_1_lag_3',
 'I_1_lag_2',
 'I_1_lag_1',
 'I_1_lag_0',
 'I_2_lag_20',
 'I_2_lag_19',
 'I_2_lag_18',
 'I_2_lag_17',
 'I_2_lag_16',
 'I_2_lag_15',
 'I_2_lag_14',
 'I_2_lag_13',
 'I_2_lag_12',
 'I_2_lag_11',
 'I_2_lag_10',
 'I_2_lag_9',
 'I_2_lag_8',
 'I_2_lag_7',
 'I_2_lag_6',
 'I_2_lag_4',
 'I_2_lag_3',
 'I_3_lag_20',
 'I_3_lag_19',
 'I_3_lag_18',
 'I_3_lag_17',
 'I_3_lag_16',
 'I_3_lag_13',
 'I_3_lag_12',
 'I_3_lag_11',
 'I_3_lag_9',
 'I_3_lag_8',
 'I_3_lag_4',
 'I_3_lag_3',
 'I_3_lag_1',
 'I_3_lag_0',
 'I_4_lag_19',
 'I_4_lag_18',
 'I_4_lag_17',
 'I_4_lag_16',
 'I_4_lag_14',
 'I_4_lag_13',
 'I_4_lag_12',
 'I_4_lag_8',
 'I_4_lag_7',
 'I_4_lag_6',
 'I_4_lag_5',
 'I_4_lag_1',
 'I_5_lag_18',
 'I_5_lag_17',
 'I_5_lag_11',
 'I_5_lag_7',
 'I_5_lag_5',
 'I_5_lag_4',
 'I_6_lag_17',
 'I_6_lag_16',
 'I_6_lag_1',
 'I_7_lag_16',
 'X_3_lag_2',
 'I_2_roc_3',
 'I_3_roc_17',
 'I_4_roc_11',
 'I_5_roc_2',
 'I_5_roc_9',
 'I_5_roc_10',
 'I_5_roc_17',
 'I_7_roc_1',
 'I_7_roc_4',
 'I_7_roc_6',
 'I_7_roc_18',
 'I_1_roc20',
 'I_4_roc20',
 'I_1_roc5',
 'X_1_roc_0',
 'X_1_roc_4',
 'X_1_roc_5',
 'X_1_roc_12',
 'X_1_roc_13',
 'X_1_roc_15',
 'X_1_roc_17',
 'X_1_roc_18',
 'X_1_roc_19',
 'X_2_roc_0',
 'X_2_roc_1',
 'X_2_roc_2',
 'X_2_roc_3',
 'X_2_roc_4',
 'X_2_roc_5',
 'X_2_roc_7',
 'X_2_roc_9',
 'X_2_roc_11',
 'X_2_roc_12',
 'X_2_roc_13',
 'X_2_roc_14',
 'X_2_roc_15',
 'X_2_roc_16',
 'X_2_roc_17',
 'X_2_roc_18',
 'X_2_roc_19',
 'X_3_roc_0',
 'X_3_roc_2',
 'X_3_roc_4',
 'X_3_roc_5',
 'X_3_roc_8',
 'X_3_roc_9',
 'X_3_roc_10',
 'X_3_roc_11',
 'X_3_roc_12',
 'X_3_roc_15',
 'X_2_roc5',
 'X_3_roc5',
 'I_1_roc5_S1',
 'I_3_roc5_S1',
 'I_5_roc5_S1',
 'I_7_roc5_S1',
 'I_1_roc5_S2',
 'I_2_roc5_S2',
 'I_3_roc5_S2',
 'I_5_roc5_S2',
 'I_6_roc5_S2',
 'I_1_roc5_S3',
 'I_2_roc5_S3',
 'I_3_roc5_S3',
 'I_7_roc5_S3',
 'I_wr_S1',
 'I_cov_11',
 'I_cov_13',
 'I_cov_15',
 'I_cov_22',
 'I_cov_24',
 'I_cov_25',
 'I_cov_26',
 'I_cov_33',
 'I_cov_42',
 'I_cov_45',
 'I_cov_54',
 'I_cov_55',
 'I_cov_65',
 'I_cov_66',
 'I_cov_74',
 'I_cov_77',
 'X_cov_13',
 'X_cov_21',
 'X_cov_22',
 'X_cov_23',
 'X_cov_31',
 'X_cov_32',
 'X_cov_33',
 'sigma',
 'SR',
 'SR_S2']

# %%
cols2 = ['I_1_lag_18',
 'I_1_lag_17',
 'I_1_lag_15',
 'I_1_lag_14',
 'I_1_lag_11',
 'I_1_lag_10',
 'I_1_lag_7',
 'I_1_lag_5',
 'I_1_lag_2',
 'I_2_lag_19',
 'I_2_lag_18',
 'I_2_lag_17',
 'I_2_lag_16',
 'I_2_lag_13',
 'I_2_lag_12',
 'I_2_lag_11',
 'I_2_lag_10',
 'I_2_lag_9',
 'I_2_lag_3',
 'I_3_lag_17',
 'I_3_lag_16',
 'I_3_lag_12',
 'I_3_lag_9',
 'I_3_lag_1',
 'I_4_lag_17',
 'I_4_lag_12',
 'I_4_lag_8',
 'I_4_lag_1',
 'I_5_lag_7',
 'I_5_lag_5',
 'I_5_lag_4',
 'I_6_lag_17',
 'I_6_lag_16',
 'I_6_lag_1',
 'I_7_lag_16',
 'X_3_lag_2',
 'I_2_roc_3',
 'I_3_roc_17',
 'I_5_roc_2',
 'I_5_roc_9',
 'I_7_roc_4',
 'I_7_roc_6',
 'I_1_roc20',
 'I_4_roc20',
 'I_1_roc5',
 'X_1_roc_0',
 'X_1_roc_4',
 'X_1_roc_5',
 'X_1_roc_12',
 'X_1_roc_13',
 'X_1_roc_15',
 'X_1_roc_17',
 'X_1_roc_18',
 'X_1_roc_19',
 'X_2_roc_0',
 'X_2_roc_1',
 'X_2_roc_2',
 'X_2_roc_3',
 'X_2_roc_4',
 'X_2_roc_7',
 'X_2_roc_9',
 'X_2_roc_11',
 'X_2_roc_12',
 'X_2_roc_13',
 'X_2_roc_14',
 'X_2_roc_15',
 'X_2_roc_16',
 'X_2_roc_17',
 'X_2_roc_18',
 'X_2_roc_19',
 'X_3_roc_2',
 'X_3_roc_5',
 'X_3_roc_8',
 'X_3_roc_9',
 'X_3_roc_10',
 'X_3_roc_11',
 'X_3_roc_12',
 'X_3_roc_15',
 'I_3_roc5_S1',
 'I_7_roc5_S1',
 'I_1_roc5_S2',
 'I_2_roc5_S2',
 'I_3_roc5_S2',
 'I_6_roc5_S2',
 'I_1_roc5_S3',
 'I_2_roc5_S3',
 'I_3_roc5_S3',
 'I_wr_S1',
 'I_cov_11',
 'I_cov_22',
 'I_cov_24',
 'I_cov_25',
 'I_cov_26',
 'I_cov_33',
 'I_cov_42',
 'I_cov_45',
 'I_cov_54',
 'I_cov_55',
 'I_cov_65',
 'I_cov_74',
 'I_cov_77',
 'X_cov_13',
 'X_cov_21',
 'X_cov_22',
 'X_cov_23',
 'X_cov_32',
 'X_cov_33',
 'sigma',
 'SR',
 'SR_S2']

# %%
cols3 = ['I_1_roc_0',
 'I_1_roc_1',
 'I_1_roc_2',
 'I_1_roc_3',
 'I_1_roc_4',
 'I_1_roc_5',
 'I_1_roc_6',
 'I_1_roc_7',
 'I_1_roc_8',
 'I_1_roc_9',
 'I_1_roc_10',
 'I_1_roc_11',
 'I_1_roc_12',
 'I_1_roc_13',
 'I_1_roc_14',
 'I_1_roc_15',
 'I_1_roc_16',
 'I_1_roc_17',
 'I_1_roc_18',
 'I_1_roc_19',
 'I_2_roc_0',
 'I_2_roc_1',
 'I_2_roc_2',
 'I_2_roc_3',
 'I_2_roc_4',
 'I_2_roc_5',
 'I_2_roc_6',
 'I_2_roc_7',
 'I_2_roc_8',
 'I_2_roc_9',
 'I_2_roc_10',
 'I_2_roc_11',
 'I_2_roc_12',
 'I_2_roc_13',
 'I_2_roc_14',
 'I_2_roc_15',
 'I_2_roc_16',
 'I_2_roc_17',
 'I_2_roc_18',
 'I_2_roc_19',
 'I_3_roc_0',
 'I_3_roc_1',
 'I_3_roc_2',
 'I_3_roc_3',
 'I_3_roc_4',
 'I_3_roc_5',
 'I_3_roc_6',
 'I_3_roc_7',
 'I_3_roc_8',
 'I_3_roc_9',
 'I_3_roc_10',
 'I_3_roc_11',
 'I_3_roc_12',
 'I_3_roc_13',
 'I_3_roc_14',
 'I_3_roc_15',
 'I_3_roc_16',
 'I_3_roc_17',
 'I_3_roc_18',
 'I_3_roc_19',
 'I_4_roc_0',
 'I_4_roc_1',
 'I_4_roc_2',
 'I_4_roc_3',
 'I_4_roc_4',
 'I_4_roc_5',
 'I_4_roc_6',
 'I_4_roc_7',
 'I_4_roc_8',
 'I_4_roc_9',
 'I_4_roc_10',
 'I_4_roc_11',
 'I_4_roc_12',
 'I_4_roc_13',
 'I_4_roc_14',
 'I_4_roc_15',
 'I_4_roc_16',
 'I_4_roc_17',
 'I_4_roc_18',
 'I_4_roc_19',
 'I_5_roc_0',
 'I_5_roc_1',
 'I_5_roc_2',
 'I_5_roc_3',
 'I_5_roc_4',
 'I_5_roc_5',
 'I_5_roc_6',
 'I_5_roc_7',
 'I_5_roc_8',
 'I_5_roc_9',
 'I_5_roc_10',
 'I_5_roc_11',
 'I_5_roc_12',
 'I_5_roc_13',
 'I_5_roc_14',
 'I_5_roc_15',
 'I_5_roc_16',
 'I_5_roc_17',
 'I_5_roc_18',
 'I_5_roc_19',
 'I_6_roc_0',
 'I_6_roc_1',
 'I_6_roc_2',
 'I_6_roc_3',
 'I_6_roc_4',
 'I_6_roc_5',
 'I_6_roc_6',
 'I_6_roc_7',
 'I_6_roc_8',
 'I_6_roc_9',
 'I_6_roc_10',
 'I_6_roc_11',
 'I_6_roc_12',
 'I_6_roc_13',
 'I_6_roc_14',
 'I_6_roc_15',
 'I_6_roc_16',
 'I_6_roc_17',
 'I_6_roc_18',
 'I_6_roc_19',
 'I_7_roc_0',
 'I_7_roc_1',
 'I_7_roc_2',
 'I_7_roc_3',
 'I_7_roc_4',
 'I_7_roc_5',
 'I_7_roc_6',
 'I_7_roc_7',
 'I_7_roc_8',
 'I_7_roc_9',
 'I_7_roc_10',
 'I_7_roc_11',
 'I_7_roc_12',
 'I_7_roc_13',
 'I_7_roc_14',
 'I_7_roc_15',
 'I_7_roc_16',
 'I_7_roc_17',
 'I_7_roc_18',
 'I_7_roc_19',
 'I_1_roc20',
 'I_2_roc20',
 'I_3_roc20',
 'I_4_roc20',
 'I_5_roc20',
 'I_6_roc20',
 'I_7_roc20',
 'I_1_roc5',
 'I_2_roc5',
 'I_3_roc5',
 'I_4_roc5',
 'I_5_roc5',
 'I_6_roc5',
 'I_7_roc5',
 'X_1_roc_0',
 'X_1_roc_1',
 'X_1_roc_2',
 'X_1_roc_3',
 'X_1_roc_4',
 'X_1_roc_5',
 'X_1_roc_6',
 'X_1_roc_7',
 'X_1_roc_8',
 'X_1_roc_9',
 'X_1_roc_10',
 'X_1_roc_11',
 'X_1_roc_12',
 'X_1_roc_13',
 'X_1_roc_14',
 'X_1_roc_15',
 'X_1_roc_16',
 'X_1_roc_17',
 'X_1_roc_18',
 'X_1_roc_19',
 'X_2_roc_0',
 'X_2_roc_1',
 'X_2_roc_2',
 'X_2_roc_3',
 'X_2_roc_4',
 'X_2_roc_5',
 'X_2_roc_6',
 'X_2_roc_7',
 'X_2_roc_8',
 'X_2_roc_9',
 'X_2_roc_10',
 'X_2_roc_11',
 'X_2_roc_12',
 'X_2_roc_13',
 'X_2_roc_14',
 'X_2_roc_15',
 'X_2_roc_16',
 'X_2_roc_17',
 'X_2_roc_18',
 'X_2_roc_19',
 'X_3_roc_0',
 'X_3_roc_1',
 'X_3_roc_2',
 'X_3_roc_3',
 'X_3_roc_4',
 'X_3_roc_5',
 'X_3_roc_6',
 'X_3_roc_7',
 'X_3_roc_8',
 'X_3_roc_9',
 'X_3_roc_10',
 'X_3_roc_11',
 'X_3_roc_12',
 'X_3_roc_13',
 'X_3_roc_14',
 'X_3_roc_15',
 'X_3_roc_16',
 'X_3_roc_17',
 'X_3_roc_18',
 'X_3_roc_19',
 'X_1_roc20',
 'X_2_roc20',
 'X_3_roc20',
 'X_1_roc5',
 'X_2_roc5',
 'X_3_roc5',
 'I_1_roc5_S1',
 'I_2_roc5_S1',
 'I_3_roc5_S1',
 'I_4_roc5_S1',
 'I_5_roc5_S1',
 'I_6_roc5_S1',
 'I_7_roc5_S1',
 'I_1_roc5_S2',
 'I_2_roc5_S2',
 'I_3_roc5_S2',
 'I_4_roc5_S2',
 'I_5_roc5_S2',
 'I_6_roc5_S2',
 'I_7_roc5_S2',
 'I_1_roc5_S3',
 'I_2_roc5_S3',
 'I_3_roc5_S3',
 'I_4_roc5_S3',
 'I_5_roc5_S3',
 'I_6_roc5_S3',
 'I_7_roc5_S3',
 'I_wr',
 'I_wr_S1',
 'I_wr_S2',
 'I_wr_S3',
 'I_cov_11',
 'I_cov_12',
 'I_cov_13',
 'I_cov_14',
 'I_cov_15',
 'I_cov_16',
 'I_cov_17',
 'I_cov_21',
 'I_cov_22',
 'I_cov_23',
 'I_cov_24',
 'I_cov_25',
 'I_cov_26',
 'I_cov_27',
 'I_cov_31',
 'I_cov_32',
 'I_cov_33',
 'I_cov_34',
 'I_cov_35',
 'I_cov_36',
 'I_cov_37',
 'I_cov_41',
 'I_cov_42',
 'I_cov_43',
 'I_cov_44',
 'I_cov_45',
 'I_cov_46',
 'I_cov_47',
 'I_cov_51',
 'I_cov_52',
 'I_cov_53',
 'I_cov_54',
 'I_cov_55',
 'I_cov_56',
 'I_cov_57',
 'I_cov_61',
 'I_cov_62',
 'I_cov_63',
 'I_cov_64',
 'I_cov_65',
 'I_cov_66',
 'I_cov_67',
 'I_cov_71',
 'I_cov_72',
 'I_cov_73',
 'I_cov_74',
 'I_cov_75',
 'I_cov_76',
 'I_cov_77',
 'X_cov_11',
 'X_cov_12',
 'X_cov_13',
 'X_cov_21',
 'X_cov_22',
 'X_cov_23',
 'X_cov_31',
 'X_cov_32',
 'X_cov_33',
 'sigma',
 'SR',
 'SR_S1',
 'SR_S2',
 'SR_S3',
 'SR_I1',
 'SR_I2',
 'SR_I3',
 'SR_I4',
 'SR_I5',
 'SR_I6',
 'SR_I7']

# %%
cols4 = ['SR_I1', 'SR_I2', 'SR_I3', 'SR_I4', 'SR_I5', 'SR_I6', 'SR_I7',
       'I_1_roc20', 'I_2_roc20', 'I_3_roc20', 'I_4_roc20', 'I_5_roc20',
       'I_6_roc20', 'I_7_roc20', 'X_1_roc20', 'X_2_roc20', 'X_3_roc20',
       'SR_S1', 'SR_S2', 'SR_S3', 'X_cov_11', 'X_cov_12', 'X_cov_13',
       'X_cov_21', 'X_cov_22', 'X_cov_23', 'X_cov_31', 'X_cov_32', 'X_cov_33',
       'SR']

# %%
cve = cross_val_score(RandomForestRegressor(criterion='mae', max_depth=2, n_jobs=10),
                X.loc[:, cols], 
                y,
               scoring='neg_mean_absolute_error',
               cv=splits)

# %%
splits = gkf.split(X.loc[:, :], y['smoothed'], id_group)
cve2 = cross_val_score(RandomForestRegressor(criterion='mae', max_depth=2, n_jobs=10),
                X.loc[:, cols2], 
                y,
               scoring='neg_mean_absolute_error',
               cv=splits)

# %%
splits = gkf.split(X.loc[:, :], y['smoothed'], id_group)
cve3 = cross_val_score(RandomForestRegressor(criterion='mae', max_depth=2, n_jobs=10),
                X.loc[:, cols3], 
                y,
               scoring='neg_mean_absolute_error',
               cv=splits)

# %%
cve.mean(), cve2.mean(), cve3.mean()
# Out:
# (-834.8093185367634, -835.3173545291581, -835.709282964194)

# %%
len(cols)
# Out:
# 167

# %%
X = pd.read_csv('./df_sharpe.csv')
y = pd.read_csv('./y_sharpe.csv')
id_group = X['IDgroup']
X = X.drop(['ID', 'IDgroup'], axis=1)
gkf = GroupKFold(5)
splits = gkf.split(X.loc[:, :], y['smoothed'], id_group)
y = y['smoothed']

# %%
rf_models = []
train_res = []
test_res = []

gkf = GroupKFold(5)
for i, (train_index, test_index) in enumerate(gkf.split(X.loc[:, :], y, id_group)):
        train_X_fold = X.iloc[train_index, :].loc[:, cols].values
        train_Y_fold = y.iloc[train_index].values
        test_X_fold = X.iloc[test_index, :].loc[:, cols].values
        test_Y_fold = y.iloc[test_index].values
        
        rf = RandomForestRegressor(criterion='mae', max_depth=2, n_jobs=10)
        rf.fit(train_X_fold, train_Y_fold)
        
        train_preds = rf.predict(train_X_fold)
        test_preds = rf.predict(test_X_fold)
        mae_train = mean_absolute_error(train_Y_fold, train_preds)
        mae_test = mean_absolute_error(test_Y_fold, test_preds)
        train_res.append(mae_train)
        test_res.append(mae_test)
        
        rf_models.append(rf)
        
np.mean(train_res), np.mean(test_res)
# Out:
# (0.4939785478757444, 0.6011119705765708)

# %%
rf_models2 = []
train_res = []
test_res = []

gkf = GroupKFold(5)
for i, (train_index, test_index) in enumerate(gkf.split(X.loc[:, :], y, id_group)):
        train_X_fold = X.iloc[train_index, :].loc[:, cols2].values
        train_Y_fold = y.iloc[train_index].values
        test_X_fold = X.iloc[test_index, :].loc[:, cols2].values
        test_Y_fold = y.iloc[test_index].values
        
        rf = RandomForestRegressor(criterion='mae', max_depth=2, n_jobs=10)
        rf.fit(train_X_fold, train_Y_fold)
        
        train_preds = rf.predict(train_X_fold)
        test_preds = rf.predict(test_X_fold)
        mae_train = mean_absolute_error(train_Y_fold, train_preds)
        mae_test = mean_absolute_error(test_Y_fold, test_preds)
        train_res.append(mae_train)
        test_res.append(mae_test)
        
        rf_models2.append(rf)
        
np.mean(train_res), np.mean(test_res)
# Out:
# (0.4971938085884612, 0.6020543091509896)

# %%
rf_models3 = []
train_res = []
test_res = []

gkf = GroupKFold(5)
for i, (train_index, test_index) in enumerate(gkf.split(X.loc[:, :], y, id_group)):
        train_X_fold = X.iloc[train_index, :].loc[:, cols3].values
        train_Y_fold = y.iloc[train_index].values
        test_X_fold = X.iloc[test_index, :].loc[:, cols3].values
        test_Y_fold = y.iloc[test_index].values
        
        rf = RandomForestRegressor(criterion='mae', max_depth=2, n_jobs=10)
        rf.fit(train_X_fold, train_Y_fold)
        
        train_preds = rf.predict(train_X_fold)
        test_preds = rf.predict(test_X_fold)
        mae_train = mean_absolute_error(train_Y_fold, train_preds)
        mae_test = mean_absolute_error(test_Y_fold, test_preds)
        train_res.append(mae_train)
        test_res.append(mae_test)
        
        rf_models3.append(rf)
        
np.mean(train_res), np.mean(test_res)
# Out:
# (0.4867632908001818, 0.611533925546496)

# %%
rf_models4 = []
train_res = []
test_res = []

gkf = GroupKFold(5)
for i, (train_index, test_index) in enumerate(gkf.split(X.loc[:, :], y, id_group)):
        train_X_fold = X.iloc[train_index, :].loc[:, cols4].values
        train_Y_fold = y.iloc[train_index].values
        test_X_fold = X.iloc[test_index, :].loc[:, cols4].values
        test_Y_fold = y.iloc[test_index].values
        
        rf = RandomForestRegressor(criterion='mae', max_depth=2, n_jobs=10)
        rf.fit(train_X_fold, train_Y_fold)
        
        train_preds = rf.predict(train_X_fold)
        test_preds = rf.predict(test_X_fold)
        mae_train = mean_absolute_error(train_Y_fold, train_preds)
        mae_test = mean_absolute_error(test_Y_fold, test_preds)
        train_res.append(mae_train)
        test_res.append(mae_test)
        
        rf_models4.append(rf)
        
np.mean(train_res), np.mean(test_res)
# Out:
# (0.5049470442967704, 0.578688882514554)

# %%
rf_models5 = []
train_res = []
test_res = []

gkf = GroupKFold(5)
for i, (train_index, test_index) in enumerate(gkf.split(X.loc[:, :], y, id_group)):
        train_X_fold = X.iloc[train_index, :].loc[:, cols5].values
        train_Y_fold = y.iloc[train_index].values
        test_X_fold = X.iloc[test_index, :].loc[:, cols5].values
        test_Y_fold = y.iloc[test_index].values
        
        rf = RandomForestRegressor(criterion='mae', max_depth=2, n_jobs=10)
        rf.fit(train_X_fold, train_Y_fold)
        
        train_preds = rf.predict(train_X_fold)
        test_preds = rf.predict(test_X_fold)
        mae_train = mean_absolute_error(train_Y_fold, train_preds)
        mae_test = mean_absolute_error(test_Y_fold, test_preds)
        train_res.append(mae_train)
        test_res.append(mae_test)
        
        rf_models5.append(rf)
        
np.mean(train_res), np.mean(test_res)
# Out:
# (0.5022663484232847, 0.5899591530890543)

# %%
rf_models6 = []
train_res = []
test_res = []

# variables anis + suppression feat importance
gkf = GroupKFold(5)
for i, (train_index, test_index) in enumerate(gkf.split(X.loc[:, :], y, id_group)):
        train_X_fold = X.iloc[train_index, :].loc[:, cols6].values
        train_Y_fold = y.iloc[train_index].values
        test_X_fold = X.iloc[test_index, :].loc[:, cols6].values
        test_Y_fold = y.iloc[test_index].values
        
        rf = RandomForestRegressor(criterion='mae', max_depth=2, n_jobs=10)
        rf.fit(train_X_fold, train_Y_fold)
        
        train_preds = rf.predict(train_X_fold)
        test_preds = rf.predict(test_X_fold)
        mae_train = mean_absolute_error(train_Y_fold, train_preds)
        mae_test = mean_absolute_error(test_Y_fold, test_preds)
        train_res.append(mae_train)
        test_res.append(mae_test)
        
        rf_models6.append(rf)
        
np.mean(train_res), np.mean(test_res)
# Out:
# (0.5043683843820175, 0.5782458979835852)

# %%
cols6 = ['SR_I1',
 'I_5_roc20',
 'X_2_roc20',
 'SR_I4',
 'I_4_roc20',
 'X_1_roc20',
 'I_3_roc20',
 'SR_I3',
 'I_7_roc20',
 'SR_I5',
 'SR_I7',
 'X_3_roc20',
 'I_1_roc20',
 'SR_I6',
 'I_6_roc20',
 'SR_I2',
 'X_cov_12',
 'X_cov_11',
 'X_cov_33',
 'X_cov_21',
 'X_cov_23',
 'SR_S3',
 'I_2_roc20',
 'X_cov_32']

# %%
from sklearn.experimental import enable_hist_gradient_boosting  # noqa
from sklearn.ensemble import HistGradientBoostingRegressor

# %%
X = pd.read_csv('./df_sharpe.csv')
y = pd.read_csv('./y_sharpe.csv')
id_group = X['IDgroup']
X = X.drop(['ID', 'IDgroup'], axis=1)
gkf = GroupKFold(5)
splits = gkf.split(X.loc[:, :], y['smoothed'], id_group)
y = y['smoothed']

# %%
rf_models6 = []
train_res = []
test_res = []

# variables anis + suppression feat importance
gkf = GroupKFold(5)
for i, (train_index, test_index) in enumerate(gkf.split(X.loc[:, :], y, id_group)):
        train_X_fold = X.iloc[train_index, :].loc[:, cols6].values 
        train_Y_fold = y.iloc[train_index].values
        test_X_fold = X.iloc[test_index, :].loc[:, cols6].values
        test_Y_fold = y.iloc[test_index].values
               
        rf = HistGradientBoostingRegressor(max_depth=2, l2_regularization=0.15,
                                          min_samples_leaf=10, learning_rate=0.2,
                                          max_leaf_nodes=15)
        rf.fit(train_X_fold, train_Y_fold)
        
        train_preds = rf.predict(train_X_fold)
        test_preds = rf.predict(test_X_fold)
        mae_train = mean_absolute_error(train_Y_fold, train_preds)
        mae_test = mean_absolute_error(test_Y_fold, test_preds)
        train_res.append(mae_train)
        test_res.append(mae_test)
        
        rf_models6.append(rf)
        
np.mean(train_res), np.mean(test_res)
# Out:
# (0.37565416431956633, 0.5693022395097986)

# %%
X.shape
# Out:
# (10000, 532)

# %%
from sklearn.model_selection import GridSearchCV

# %%
gkf = GroupKFold(5)
params = {
    'learning_rate': [0.2, 0.21],
    'min_samples_leaf': [5, 8, 10],
    'max_iter': [50, 100, 150],
    'max_leaf_nodes': [15, 30, 50]
}

gre = GridSearchCV(HistGradientBoostingRegressor(max_depth=2,
                                                 l2_regularization=0.15),
                  params,
                  scoring='neg_mean_absolute_error',
                  n_jobs=10,
                  cv=gkf.split(X.loc[:, :], y, id_group))
gre.fit(X.loc[:, :], y)
# Out:
# GridSearchCV(cv=<generator object _BaseKFold.split at 0x7f6b5f6d1ad0>,
#              error_score=nan,
#              estimator=HistGradientBoostingRegressor(l2_regularization=0.0,
#                                                      learning_rate=0.1,
#                                                      loss='least_squares',
#                                                      max_bins=255,
#                                                      max_depth=None,
#                                                      max_iter=100,
#                                                      max_leaf_nodes=31,
#                                                      min_samples_leaf=20,
#                                                      n_iter_no_change=None,
#                                                      random_state=None,
#                                                      scoring=None, tol=1e-07,
# ...

# %%
gre.best_params_
# Out:
# {'l2_regularization': 0.15,
#  'learning_rate': 0.2,
#  'max_depth': 2,
#  'max_iter': 100,
#  'max_leaf_nodes': 15,
#  'min_samples_leaf': 10}

# %% [markdown]
# ### Sauvegarde des modèles

# %%
for i, model in enumerate(rf_models6):
    dump(model, './model_dir/' + 'model_' + str(i) + '.joblib')

# %% [markdown]
# ## Prediction sur la base de test

# %% [markdown]
# ### Chargement des modèles

# %%
models = []
for i in range(5):
    models.append(load('./model_dir/' + 'model_' + str(i) + '.joblib'))

# %% [markdown]
# ### Prédiction

# %%
X = pd.read_csv('./df_sharpe.csv')
X = X.drop(['ID', 'IDgroup'], axis=1).loc[:, cols6]

results = []
for model in models:
    res = model.predict(X)
    results.append(res)

# %%
test_res_df = pd.DataFrame(results).T
test_res_df.mean(axis=1)
# Out:
# 0       0.123610
# 1       0.481275
# 2       0.466853
# 3       0.194228
# 4       0.605021
#           ...
# 9995    0.125632
# 9996    0.467387
# 9997    0.284946
# 9998    0.729524
# 9999    0.381083
# Length: 10000, dtype: float64
